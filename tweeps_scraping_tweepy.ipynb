# %% [markdown]
# # Tweeps scraping
#
# ## Introduction
# Scrapping twitter handles of popular users from twitter using tweepy. Geotags and hashtags are used to get Kenyan tweets from which user Ids are extracted. The popular users (determined by followers and friends) are added to the dataframe and the less popular ones dropped.
#
# The requests are split into batches in order to have an easy time to pinpoint errors when they arise.
#
# ## Table of Contents
# 1. [Libraries](#Libraries)
# 2. [Kenya's co-ordinates](#geo)
# 3. [Geo Scraper](#Geo-Scraper)
# 4. [Keyword Scraper](#Keyword-Scraper)
# 5. [Mega DataFrame](#Mega-Df)

# %% [markdown]
# ### Libraries

# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import pandas as pd
import os, sys

import fire

import sys
import os
import json
import matplotlib.pyplot as plt
import re
import string

import matplotlib.dates as mdates
import seaborn as sns

# to view all columns
pd.set_option("display.max.columns", None)

import tweepy
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy import API
from tweepy import Cursor
from datetime import datetime, date, time, timedelta
from collections import Counter
import sys


import preprocessor as p

# %% [markdown]
# ### geo
#  The first step is to get Kenya's geo cordinates from twitter then use it with the search method to fetch Kenya tweets from Jan 1st this year. From the tweets the users are extracted. The limit is set to 2k users/tweets, from which a few 800 will be selected based on popularity.

# %%
consumer_key = os.environ.get('consumer_key')
consumer_secret = os.environ.get('consumer_secret')
access_token = os.environ.get('access_token')
access_token_secret = os.environ.get('access_token_secret')

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
auth_api = API(auth, wait_on_rate_limit=True)

places = auth_api.geo_search(query="KENYA", granularity="country")
place_id = places[0].id
places

# %% [markdown]
# ### Geo Scraper

# %%
tweets = tweepy.Cursor(auth_api.search,
                       geocode="0.0236,37.9062,530km", since_id = '2020-05-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

    
data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
users_df = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
users_df.to_csv('starting users.csv')
users_df.head()
# Out:
#        screen_name  followers  friends  \
# 0       tyra_gracy        333      317
# 1            etadv       4415     4285
# 2    LaRecetteNwar        391      489
# 3   ParagraphKenya        184      151
# 4  BenjaminsOtenge       1127     5002
#
#                                          description  tweets
# 0                                              FAITH     183
# 1              Advocate, Chairman LSK Nairobi Branch    9745
# 2  french producer • credits : ISK • Bino • Jeune...    5628
# 3                            Making News Interesting   39594
# 4  Male|Politik|Academician|\n\nA teacher by prof...   12415

# %%
tweets = tweepy.Cursor(auth_api.search,
                       geocode="0.0236,37.9062,530km", since_id = '2020-06-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_2 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_2.to_csv('df_2 users.csv')
df_2.head()
# Out:
#       screen_name  followers  friends  \
# 0    EmmaOltOlato       4169     3991
# 1       AmbuchiJR         45       71
# 2         mtieno_        233      425
# 3  JonathanKaribu      12253     6364
# 4        2142bebe          9       61
#
#                                          description  tweets
# 0  Fashion Model | King of the Iteso  | Civil Eng...    4259
# 1  Writer, Photographer and Screenplay Director. ...      37
# 2  Tech Enthusiast | Born Sinner | A child of God...     903
# 3  God_fearing, Optimist,Always  Faithful and humble   61646
# 4                                                       3793

# %%
tweets = tweepy.Cursor(auth_api.search,
                       geocode="0.0236,37.9062,530km", since_id = '2020-07-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_3 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_3.to_csv('df_3 users.csv')
df_3.head()
# Out:
#      screen_name  followers  friends  \
# 0      purity_ng      10225      137
# 1        ngubesi        825     5000
# 2  Jabuto_Jabuto       2117      191
# 3   chief_sultan       6966     5168
# 4     jdrizzy254      27031    13192
#
#                                          description  tweets
# 0  Loves good Music,lover of life/Daughter/Sister...   46303
# 1                                                       4167
# 2  Agribusiness Strategist | Agripreneur | Projec...   59984
# 3                                        🅖🅞🅓'🅢 🅟🅛🅐🅝.   42889
# 4  God is above all \nArsenal fan 🔴🔴🔴\neconomist\...   43855

# %%
tweets = tweepy.Cursor(auth_api.search,
                       geocode="0.0236,37.9062,530km", since_id = '2020-04-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_01 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_01.to_csv('df_01 users.csv')
df_01.head()
# Out:
#        screen_name  followers  friends  \
# 0    juscloedenise       7789     7524
# 1  ErickssonOdhia2        427      770
# 2    kidaha_alfred        411      316
# 3  anselme_kwizera          7      125
# 4         DanKweno          9       70
#
#                                          description  tweets
# 0                                          Not today   15526
# 1  I'm a happy soul full of intrigue and colors\n...    9591
# 2  A Communication Lecturer at Multimedia Univers...     159
# 3                             Am proud to be Rwandan      21
# 4                                                         79

# %%
tweets = tweepy.Cursor(auth_api.search,
                       geocode="0.0236,37.9062,530km", since_id = '2020-03-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_02 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_02.to_csv('df_02 users.csv')
df_02.head()
# Out:
#        screen_name  followers  friends  \
# 0         mr_Okabi        656      493
# 1         SDEKenya      53648      280
# 2  Catalyst_Darsil       6006     1320
# 3    EdgarbrwnBrwn       2386     4999
# 4    NzauPriscilla        879      935
#
#                                          description  tweets
# 0  Happiness is a myth | Manchester United Fan | ...   11872
# 1  We take Entertainment seriously! Ultimate Keny...  144816
# 2  Lunatic psycho maniac💯💯😂\nSocial influencer\nT...    4535
# 3  Addicted to Reggae #VybezRadioke /RaceWalking ...   37867
# 4  Finance and Banking (Mauritius 2019). Commerce...    6540

# %%
tweets = tweepy.Cursor(auth_api.search,
                       geocode="0.0236,37.9062,530km", since_id = '2020-02-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_03 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_03.to_csv('df_03 users.csv')
df_03.head()
# Out:
#        screen_name  followers  friends  \
# 0      VinnieBaite      17620      854
# 1  _sisiosontogago        789      269
# 2          Dayliff      42799    28808
# 3       iam_jaymoe      11919      674
# 4   wanjerililiank        516      611
#
#                                          description  tweets
# 0  ●Twitter Professor ●Actor ●Film technologist ●...   14549
# 1               si mika ang katumbas ng habang-buhay   38105
# 2  We are the leaders in Water & Energy solutions...    6008
# 3                                                      23368
# 4  born n brought up ni kiambu county. working in...    1843

# %%
tweets = tweepy.Cursor(auth_api.search,
                       geocode="0.0236,37.9062,530km", since_id = '2020-01-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_04 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_04.to_csv('df_04 users.csv')
df_04.head()
# Out:
#        screen_name  followers  friends  \
# 0        Vikemu_Ke       4232     3243
# 1        GKILINDAH          2       25
# 2     SamuelOmerhi       1064     1242
# 3  Isebania_Finest       3447     4993
# 4       pizzainnke       1458       92
#
#                                          description  tweets
# 0  🌟\nCfc⚽\nMy Love For Football Is Underrated 😅\...   18796
# 1                                                         40
# 2                                THE NEXT BIG NAME‼️     830
# 3  #Dm for business promotions and Ads. |We are h...    4620
# 4      Giving you nothing but the best, yummy Pizza!    1301

# %%
tweets = tweepy.Cursor(auth_api.search,
                       geocode="0.0236,37.9062,530km", since_id = '2019-12-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_05 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_05.to_csv('df_05 users.csv')
df_05.head()
# Out:
#     screen_name  followers  friends  \
# 0  BeckyKwagala        620      599
# 1    Kubaimugo1        159     1132
# 2   Kush_Kahima       2153     1527
# 3   KarokiNjogu       1351     1252
# 4  Jr_LincolnKE     122464     1592
#
#                                          description  tweets
# 0  Loves to cook. 🤗 Potential public speaker. Gun...    1274
# 1  Pauline njeris husband father of Wambui n Loui...     447
# 2  Student🌺 || Mark 10:27 || @Arsenal die hard ||...    2303
# 3       Contributing To Entropy Since 1998.\n🇰🇪 ➡️ 🌍    7693
# 4  Your Favourite Voice of Reason! Digital Market...   54243

# %% [markdown]
# #### Geo df

# %%
df = pd.concat([users_df, df_2, df_3])
df.shape
# Out:
# (6000, 5)

# %%
df['popularity'] = df['followers'] - df['friends']
df = df.sort_values(by = 'popularity', ascending = False)
df = df.drop_duplicates(subset ="screen_name") 
df.shape
# Out:
# (3162, 6)

# %%
# Drop all users with popularity scores less than 50k
new_df = df[df.popularity >= 50000]
new_df.shape
# Out:
# (62, 6)

# %%
new_df
# Out:
#          screen_name  followers  friends  \
# 1639  citizentvkenya    2715770      219
# 887         ntvkenya    2551044      262
# 1684     dailynation    2142307      262
# 1269      RobertAlai    1498640     3353
# 1569         CKirubi    1432476     1091
# ...              ...        ...      ...
# 247       DorahManya      32044      367
# 230         holydave      34236     2798
# 1742        Lasha254      54219    23019
# 1029        SKachima      34059     3419
# 1329   discjockeyvin      30528      356
#
#                                             description  tweets  popularity
# 1639  Kenya's Premier TV Station. Breaking News / En...  535035     2715551
# 887   LIVE STREAM: https://t.co/BrEeOBOxu6 _________...  491465     2550782
# 1684  Welcome to Daily Nation on Twitter, for instan...  553869     2142045
# 1269  The Equalizer | There’s no comfort in the trut...  244149     1495287
# 1569  Media Owner | Entrepreneur | Mentor. A trailbl...   27725     1431385
# ...                                                 ...     ...         ...
# 247   Award winning Radio Presenter |God fearing |Yo...  189944       31677
# 230   PhD Student | Financial Modelling Expert | Art...   38324       31438
# 1742  I'm not your ordinary B 🙄 Girls who know sport...   11965       31200
# 1029   Simba SC ❤️ManUtd ❤️ Libra ⭐ Good 🎶🇹🇿 Psalm 23✌️   33308       30640
# 1329  PROFESSIONAL DJ (CLUB, MOBILE, TV & RADIO, CON...    3133       30172
#
# [87 rows x 6 columns]

# %% [markdown]
# ### Keyword Scraper

# %%
tweets = tweepy.Cursor(auth_api.search,q = 'Kenya', since_id = '2020-07-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_4 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_4.to_csv('df_4 users.csv')
df_4.head()
# Out:
#     screen_name  followers  friends  \
# 0  valleysOfGod       1972     1980
# 1   spinkingske        696      117
# 2      DNyarere          7        0
# 3      luckydun        127      270
# 4    _matheka_a        587      384
#
#                                          description  tweets
# 0  political scientist,,upcoming entrepreneur,,so...    1189
# 1  The Bicycle is a simple Solution to some of th...    1944
# 2                                                        601
# 3                                                        741
# 4                                                       8915

# %%
tweets = tweepy.Cursor(auth_api.search,q = 'Kenya', since_id = '2020-06-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_5 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_5.to_csv('df_5 users.csv')
df_5.head()
# Out:
#     screen_name  followers  friends  \
# 0    DStv_Kenya     341008    12213
# 1  iam_warloque        412      398
# 2       its_vus       1692     1446
# 3     80daysbot          9        0
# 4    TheKimutai      10702     3692
#
#                                          description  tweets
# 0  DStv is Kenya's top entertainment destination....  317107
# 1                                         #LFC #30BG     366
# 2                                                       9253
# 3             80 days of botting around the world :)   30836
# 4  Let go your earthly tether. Enter the void. Em...  206293

# %%
tweets = tweepy.Cursor(auth_api.search,q = 'Kenya', since_id = '2020-05-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_6 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_6.to_csv('df_6 users.csv')
df_6.head()
# Out:
#        screen_name  followers  friends  \
# 0       KJeremiahN       2109      660
# 1          annitii       2402     2510
# 2  DaimaGreenSpace         39       47
# 3           geonal       1335      872
# 4  mohd_Hassan_Ali        388      180
#
#                                          description  tweets
# 0  Outgoing and easy to associate with...Any view...  109414
# 1                          FOLLOWING 🇰🇪 KENYANS ONLY    6483
# 2       Advocating for inclusive GreenSpaces for all      37
# 3  Eccl. 9:11. Husband. Dreamer. Father.\nStudent...   49244
# 4        So humble for human beings & Slave of ALLAH    1344

# %%
tweets = tweepy.Cursor(auth_api.search,q = 'Kenya', since_id = '2020-04-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_7 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_7.to_csv('df_7 users.csv')
df_7.head()
# Out:
#    screen_name  followers  friends  \
# 0     _dazils_        467      165
# 1    iamjoseh_      46577      741
# 2      Waambui      35726       68
# 3     drewgash         59       48
# 4  lewys_chris         94      421
#
#                                          description  tweets
# 0               Fine young man with an old man mind.   28108
# 1   A Human. Being. my back up account 👉🏾 @iam_joseh  249788
# 2  “The capacity to learn is a gift; The ability ...    5992
# 3                         African socialist admirer.    4038
# 4  Director Ndege Tausi https://t.co/fzuLaCzFfj A...     777

# %%
tweets = tweepy.Cursor(auth_api.search,q = 'Kenya', since_id = '2020-03-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_8 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_8.to_csv('df_8 users.csv')
df_8.head()
# Out:
#       screen_name  followers  friends  \
# 0   AherezaJanice       1037     1199
# 1        _nt__tn_        319      299
# 2         HonOuko        303      331
# 3       split2tee        523      521
# 4  Wellington_ILO        819      294
#
#                                          description  tweets
# 0  Environmentalist🍃🌿🍀\nDancer,less have fun 😅\nB...     303
# 1  tu81 ee26, music addiction, namneung × noey × ...  137550
# 2                               change is inevitable     522
# 3  Humanitarian at heart, educator and an ardent ...    4217
# 4  This is the Official Twitter Account for the I...    2308

# %%
tweets = tweepy.Cursor(auth_api.search,q = 'Kenya', since_id = '2020-02-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_9 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_9.to_csv('df_9 users.csv')
df_9.head()
# Out:
#        screen_name  followers  friends  \
# 0         Am0n_0ff        163      149
# 1   ItsArnoldOduor       3604     3834
# 2         voyegram         78      243
# 3          Scanoma        595      392
# 4  RoselyneNyabon4         35       58
#
#                                          description  tweets
# 0  Africa4Africa//\n\nAfrica should be equal trad...    6104
# 1          Start small & stay consistent..\n\n+254🇰🇪    5480
# 2  Travels and Tours Company\n\nVOVEGRAM TOURS & ...      27
# 3                                            日々是ぜ〜ぜ〜   41943
# 4                                                        876

# %%
tweets = tweepy.Cursor(auth_api.search,q = 'Kenya', since_id = '2020-01-01').items(2000)
users = []
followers = []
friends = []
description = []
tweet_count = []
for status in tweets:
    name = status.user.screen_name
    desc = status.user.description
    number_of_tweets = status.user.statuses_count
    following = status.user.friends_count
    follower = status.user.followers_count
    users.append(name)
    followers.append(follower)
    friends.append(following)
    description.append(desc)
    tweet_count.append(number_of_tweets) 

data = {'screen_name':users, 'followers':followers, 'friends':friends, 'description':description, 'tweets':tweet_count}
df_0 = pd.DataFrame(data)
    
#     df['screen_name'] = users
#     df['location'] = location
    
df_0.to_csv('df_0 users.csv')
df_0.head()
# Out:
#    screen_name  followers  friends  \
# 0     kenya_pu        371      232
# 1     nanga_tp      18993     2040
# 2    KenInvest      20513      384
# 3  Njeriwaridi        334      143
# 4    ilegacy15         54      239
#
#                                          description  tweets
# 0  現存する最古のｼﾝﾒの深海に溺れる青担ﾄﾆ担箱推し。妄想絵を描く酔払い。成人式は遥か昔 妄想...   58113
# 1  Luyotilo Holdings || Stay patient and trust yo...   37994
# 2  Kenya Investment Authority (KenInvest) is a Go...    7503
# 3  Investment. Impact. Travel.Environment\n\nWorr...   14381
# 4                           My truth might be a lie.    1199

# %% [markdown]
# #### Remaining dataframes

# %%
df_k = pd.concat([df_4, df_5, df_6, df_7, df_8, df_9, df_0])
df_k.shape
# Out:
# (14000, 5)

# %%
df_k['popularity'] = df_k['followers'] - df_k['friends']
new_df_2 = df_k[df_k.popularity >= 50000]
new_df_2 = new_df_2.drop_duplicates(subset ="screen_name") 
new_df_2.shape
# Out:
# (116, 6)

# %%
new_df_2
# Out:
#          screen_name  followers  friends  \
# 43      RoadAlertsKE     162406      490
# 79        coldtusker     147140     3716
# 91      pressecitron     649614     2160
# 105         ntvkenya    2551233      262
# 110   CofekRebranded     139997    19373
# ...              ...        ...      ...
# 957    TheKenyanPost      51940      418
# 1146     KBCChannel1     310081     1750
# 1151    swahilitimes     581701        0
# 1189        WMutunga    1007081      847
# 1217   ReutersAfrica     738848      341
#
#                                             description  tweets  popularity
# 43    Official Twitter Account for Road Alerts KE. S...  123136      161916
# 79                                         Simply me...  361943      143424
# 91    Connectez-vous à l'innovation ! #Pressecitron1...   64786      647454
# 105   LIVE STREAM: https://t.co/BrEeOBOxu6 _________...  491479     2550971
# 110   COFEK is Kenya and Africa's Premier Consumer P...   44135      120624
# ...                                                 ...     ...         ...
# 957   News, Politics, Entertainment, Gossip, Feature...  326473       51522
# 1146  Kenya's National Broadcaster, bringing you sto...  203064      308331
# 1151  Habari | Elimu | Burudani | swahilitimes@gmail...   53538      581701
# 1189    INSPIRING THE YOUTH TO CREATE BETTER TOMORROWS.   34382     1006234
# 1217  Reuters Africa provides a feed of our latest n...   39437      738507
#
# [116 rows x 6 columns]

# %% [markdown]
# ### Mega Df

# %%
full_df = pd.concat([new_df, new_df_2])
full_df = full_df.drop_duplicates(subset ="screen_name") 
full_df.to_csv('mega1.csv')

# %% [markdown]
# #### [Back to top](#Tweeps-scraping)
